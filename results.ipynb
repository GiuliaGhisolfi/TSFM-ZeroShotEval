# %%
import pandas as pd
import numpy as np

# %%
chronos_base_path = "results/chronos/chronos_bolt_base_results.csv"
chronos_small_path = "results/chronos/chronos_bolt_small_results.csv"
chronos_mini_path = "results/chronos/chronos_bolt_minimize_results.csv"
chronos_tiny_path = "results/chronos/chronos_bolt_tiny_results.csv"

timesfm1_path = "results/timesfm/timesfm1_results.csv"
timesfm2_path = "results/timesfm/timesfm2_results.csv"

# %%
chronos_base = pd.read_csv(chronos_base_path)

# %%
def path_to_df(path):
    df = pd.read_csv(path)
    df = df[["dataset", "model", "eval_metrics/MASE[0.5]", "domain", "num_variates"]]
    df = df.rename(columns={"eval_metrics/MASE[0.5]": "MASE"})
    return df

# %%
chronos_base_df = path_to_df(chronos_base_path)
chronos_base_df
# Out:
#                              dataset              model       MASE  \
# 0     bizitobs_application/10S/short  chronos_bolt_base   5.533290
# 1    bizitobs_application/10S/medium  chronos_bolt_base   9.720338
# 2      bizitobs_application/10S/long  chronos_bolt_base  10.483795
# 3              bizitobs_l2c/5T/short  chronos_bolt_base   0.278185
# 4             bizitobs_l2c/5T/medium  chronos_bolt_base   0.877710
# 5               bizitobs_l2c/5T/long  chronos_bolt_base   1.240735
# 6             jena_weather/10T/short  chronos_bolt_base   0.305514
# 7            jena_weather/10T/medium  chronos_bolt_base   0.610205
# 8              jena_weather/10T/long  chronos_bolt_base   0.656684
# 9         bizitobs_service/10S/short  chronos_bolt_base   3.298598
# 10       bizitobs_service/10S/medium  chronos_bolt_base   4.957952
# 11         bizitobs_service/10S/long  chronos_bolt_base   5.280270
# 12              bizitobs_l2c/H/short  chronos_bolt_base   0.432270
# 13             bizitobs_l2c/H/medium  chronos_bolt_base   0.495206
# 14               bizitobs_l2c/H/long  chronos_bolt_base   0.555711
# 15                     solar/D/short  chronos_bolt_base   0.981772
# 16   bitbrains_fast_storage/5T/short  chronos_bolt_base   0.744893
# 17  bitbrains_fast_storage/5T/medium  chronos_bolt_base   1.047697
#
#           domain  num_variates
# 0   Web/CloudOps             2
# 1   Web/CloudOps             2
# 2   Web/CloudOps             2
# 3   Web/CloudOps             7
# 4   Web/CloudOps             7
# 5   Web/CloudOps             7
# 6         Nature            21
# 7         Nature            21
# 8         Nature            21
# 9   Web/CloudOps             2
# 10  Web/CloudOps             2
# 11  Web/CloudOps             2
# 12  Web/CloudOps             7
# 13  Web/CloudOps             7
# 14  Web/CloudOps             7
# 15        Energy             1
# 16  Web/CloudOps             2
# 17  Web/CloudOps             2

# %%
chronos_base
# Out:
#                              dataset              model  \
# 0     bizitobs_application/10S/short  chronos_bolt_base
# 1    bizitobs_application/10S/medium  chronos_bolt_base
# 2      bizitobs_application/10S/long  chronos_bolt_base
# 3              bizitobs_l2c/5T/short  chronos_bolt_base
# 4             bizitobs_l2c/5T/medium  chronos_bolt_base
# 5               bizitobs_l2c/5T/long  chronos_bolt_base
# 6             jena_weather/10T/short  chronos_bolt_base
# 7            jena_weather/10T/medium  chronos_bolt_base
# 8              jena_weather/10T/long  chronos_bolt_base
# 9         bizitobs_service/10S/short  chronos_bolt_base
# 10       bizitobs_service/10S/medium  chronos_bolt_base
# 11         bizitobs_service/10S/long  chronos_bolt_base
# 12              bizitobs_l2c/H/short  chronos_bolt_base
# 13             bizitobs_l2c/H/medium  chronos_bolt_base
# 14               bizitobs_l2c/H/long  chronos_bolt_base
# 15                     solar/D/short  chronos_bolt_base
# 16   bitbrains_fast_storage/5T/short  chronos_bolt_base
# 17  bitbrains_fast_storage/5T/medium  chronos_bolt_base
#
#     eval_metrics/MSE[mean]  eval_metrics/MSE[0.5]  eval_metrics/MAE[0.5]  \
# 0             1.687789e+07           1.687789e+07            1702.112639
# 1             3.534478e+07           3.534478e+07            2822.695417
# 2             3.485454e+07           3.485454e+07            3006.740556
# 3             2.117333e+01           2.117333e+01               2.697071
# 4             1.825773e+02           1.825773e+02               8.885805
# 5             3.776366e+02           3.776366e+02              13.468461
# 6             9.900176e+02           9.900176e+02               6.454505
# 7             1.674398e+03           1.674398e+03              10.419221
# 8             1.990740e+03           1.990740e+03              11.394973
# 9             7.422826e+04           7.422826e+04              82.122943
# 10            1.786413e+05           1.786413e+05             135.314325
# 11            2.502791e+05           2.502791e+05             159.243016
# 12            5.659242e+01           5.659242e+01               4.475569
# 13            7.400342e+01           7.400342e+01               4.934654
# 14            7.746104e+01           7.746104e+01               5.131364
# 15            1.383225e+05           1.383225e+05             251.544115
# 16            2.142732e+06           2.142732e+06             184.894024
# 17            3.324052e+06           3.324052e+06             278.523082
#
#     eval_metrics/MASE[0.5]  eval_metrics/MAPE[0.5]  eval_metrics/sMAPE[0.5]  \
# 0                 5.533290                0.082112                 0.080056
# 1                 9.720338                0.137735                 0.134523
# 2                10.483795                0.146233                 0.144416
# 3                 0.278185                0.143535                 0.209422
# 4                 0.877710                0.572767                 0.880119
# 5                 1.240735                0.898167                 1.243097
# 6                 0.305514                0.330297                 0.568465
# 7                 0.610205                0.735241                 0.672396
# 8                 0.656684                0.749881                 0.681780
# 9                 3.298598                0.508486                 0.120418
# 10                4.957952                0.808490                 0.169111
# 11                5.280270                1.091899                 0.187947
# 12                0.432270                0.395127                 0.607594
# 13                0.495206                0.499253                 0.755523
# 14                0.555711                0.608672                 0.786079
# 15                0.981772                1.136386                 0.421465
# 16                0.744893                2.367742                 0.763200
# 17                1.047697                3.800107                 0.824621
#
#     eval_metrics/MSIS  eval_metrics/RMSE[mean]  eval_metrics/NRMSE[mean]  \
# 0           39.435796              4108.270786                  0.158440
# 1          226.308365              5945.147884                  0.233448
# 2          267.421760              5903.773076                  0.227685
# 3            2.944857                 4.601449                  0.158032
# 4           26.376949                13.512115                  0.710936
# 5           42.979638                19.432874                  1.091127
# 6            2.365053                31.464544                  0.195434
# 7           14.138299                40.919412                  0.251122
# 8           17.292167                44.617715                  0.273023
# 9           23.688710               272.448631                  0.201839
# 10         118.266563               422.659781                  0.318104
# 11         135.989375               500.279067                  0.370623
# 12           2.824355                 7.522793                  0.405498
# 13           6.702805                 8.602524                  0.520896
# 14          10.303878                 8.801195                  0.537602
# 15           5.836721               371.917287                  0.537294
# 16          15.060324              1463.807286                  4.595993
# 17          32.331918              1823.198287                  5.539380
#
#     eval_metrics/ND[0.5]  eval_metrics/mean_weighted_sum_quantile_loss  \
# 0               0.065644                                      0.053958
# 1               0.110839                                      0.103502
# 2               0.115958                                      0.108976
# 3               0.092628                                      0.074353
# 4               0.467524                                      0.445441
# 5               0.756234                                      0.738040
# 6               0.040091                                      0.032645
# 7               0.063943                                      0.057119
# 8               0.069728                                      0.063839
# 9               0.060839                                      0.050021
# 10              0.101841                                      0.095216
# 11              0.117972                                      0.111931
# 12              0.241245                                      0.189003
# 13              0.298801                                      0.254430
# 14              0.313439                                      0.277636
# 15              0.363396                                      0.287363
# 16              0.580522                                      0.453542
# 17              0.846230                                      0.755439
#
#           domain  num_variates
# 0   Web/CloudOps             2
# 1   Web/CloudOps             2
# 2   Web/CloudOps             2
# 3   Web/CloudOps             7
# 4   Web/CloudOps             7
# 5   Web/CloudOps             7
# 6         Nature            21
# 7         Nature            21
# 8         Nature            21
# 9   Web/CloudOps             2
# 10  Web/CloudOps             2
# 11  Web/CloudOps             2
# 12  Web/CloudOps             7
# 13  Web/CloudOps             7
# 14  Web/CloudOps             7
# 15        Energy             1
# 16  Web/CloudOps             2
# 17  Web/CloudOps             2

# %%
chronos_base[["dataset", "model", "eval_metrics/MASE[0.5]", "domain", "num_variates"]]
# Out:
#                              dataset              model  \
# 0     bizitobs_application/10S/short  chronos_bolt_base
# 1    bizitobs_application/10S/medium  chronos_bolt_base
# 2      bizitobs_application/10S/long  chronos_bolt_base
# 3              bizitobs_l2c/5T/short  chronos_bolt_base
# 4             bizitobs_l2c/5T/medium  chronos_bolt_base
# 5               bizitobs_l2c/5T/long  chronos_bolt_base
# 6             jena_weather/10T/short  chronos_bolt_base
# 7            jena_weather/10T/medium  chronos_bolt_base
# 8              jena_weather/10T/long  chronos_bolt_base
# 9         bizitobs_service/10S/short  chronos_bolt_base
# 10       bizitobs_service/10S/medium  chronos_bolt_base
# 11         bizitobs_service/10S/long  chronos_bolt_base
# 12              bizitobs_l2c/H/short  chronos_bolt_base
# 13             bizitobs_l2c/H/medium  chronos_bolt_base
# 14               bizitobs_l2c/H/long  chronos_bolt_base
# 15                     solar/D/short  chronos_bolt_base
# 16   bitbrains_fast_storage/5T/short  chronos_bolt_base
# 17  bitbrains_fast_storage/5T/medium  chronos_bolt_base
#
#     eval_metrics/MASE[0.5]        domain  num_variates
# 0                 5.533290  Web/CloudOps             2
# 1                 9.720338  Web/CloudOps             2
# 2                10.483795  Web/CloudOps             2
# 3                 0.278185  Web/CloudOps             7
# 4                 0.877710  Web/CloudOps             7
# 5                 1.240735  Web/CloudOps             7
# 6                 0.305514        Nature            21
# 7                 0.610205        Nature            21
# 8                 0.656684        Nature            21
# 9                 3.298598  Web/CloudOps             2
# 10                4.957952  Web/CloudOps             2
# 11                5.280270  Web/CloudOps             2
# 12                0.432270  Web/CloudOps             7
# 13                0.495206  Web/CloudOps             7
# 14                0.555711  Web/CloudOps             7
# 15                0.981772        Energy             1
# 16                0.744893  Web/CloudOps             2
# 17                1.047697  Web/CloudOps             2

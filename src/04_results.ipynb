# %%
import pandas as pd
import numpy as np

# %%
chronos_base_path = "results/chronos/chronos_bolt_base_results.csv"
chronos_small_path = "results/chronos/chronos_bolt_small_results.csv"
chronos_mini_path = "results/chronos/chronos_bolt_mini_results.csv"
chronos_tiny_path = "results/chronos/chronos_bolt_tiny_results.csv"

timesfm1_path = "results/timesfm/timesfm1_results.csv"
timesfm2_path = "results/timesfm/timesfm2_results.csv"

# %%
def path_to_df(path):
    df = pd.read_csv(path)
    df = df[["dataset", "domain", "num_variates", "model",
        "eval_metrics/MASE[0.5]", "eval_metrics/mean_weighted_sum_quantile_loss"]]
    df = df.rename(columns={"eval_metrics/MASE[0.5]": "MASE"})
    df = df.rename(columns={"eval_metrics/mean_weighted_sum_quantile_loss": "Qloss"})
    return df

# %%
chronos_base_df = path_to_df(chronos_base_path)
chronos_base_df.head()
# Out:
#                            dataset        domain  num_variates  \
# 0   bizitobs_application/10S/short  Web/CloudOps             2
# 1  bizitobs_application/10S/medium  Web/CloudOps             2
# 2    bizitobs_application/10S/long  Web/CloudOps             2
# 3            bizitobs_l2c/5T/short  Web/CloudOps             7
# 4           bizitobs_l2c/5T/medium  Web/CloudOps             7
#
#                model       MASE     Qloss
# 0  chronos_bolt_base   5.533290  0.053958
# 1  chronos_bolt_base   9.720338  0.103502
# 2  chronos_bolt_base  10.483795  0.108976
# 3  chronos_bolt_base   0.278185  0.074353
# 4  chronos_bolt_base   0.877710  0.445441

# %%
chronos_small_df = path_to_df(chronos_small_path)
chronos_mini_df = path_to_df(chronos_mini_path)
chronos_tiny_df = path_to_df(chronos_tiny_path)

timesfm1_df = path_to_df(timesfm1_path)
timesfm2_df = path_to_df(timesfm2_path)

# %%
# dataset with Mase
all_df = pd.concat([chronos_base_df, chronos_small_df, chronos_mini_df, chronos_tiny_df,
    timesfm1_df, timesfm2_df], ignore_index=True)

all_df["MASE"] = pd.to_numeric(all_df["MASE"], errors="coerce")
all_df["rank_MASE"] = all_df.groupby(["dataset"])["MASE"].rank(method="min")

all_df["Qloss"] = pd.to_numeric(all_df["Qloss"], errors="coerce")
all_df["rank_Qloss"] = all_df.groupby(["dataset"])["Qloss"].rank(method="min")

all_df["Rank"] = all_df["rank_MASE"] + all_df["rank_Qloss"] / 2

all_df = all_df[all_df["dataset"] != "dataset"]

all_df
# Out:
#                              dataset        domain  num_variates  \
# 0     bizitobs_application/10S/short  Web/CloudOps             2
# 1    bizitobs_application/10S/medium  Web/CloudOps             2
# 2      bizitobs_application/10S/long  Web/CloudOps             2
# 3              bizitobs_l2c/5T/short  Web/CloudOps             7
# 4             bizitobs_l2c/5T/medium  Web/CloudOps             7
# ..                               ...           ...           ...
# 205              jena_weather/H/long        Nature            21
# 206                   solar/10T/long        Energy             1
# 207                     solar/H/long        Energy             1
# 208    bizitobs_application/10S/long  Web/CloudOps             2
# 209        bizitobs_service/10S/long  Web/CloudOps             2
#
#                  model       MASE     Qloss  rank_MASE  rank_Qloss  Rank
# 0    chronos_bolt_base   5.533290  0.053958        3.0         3.0   4.5
# 1    chronos_bolt_base   9.720338  0.103502        3.0         3.0   4.5
# 2    chronos_bolt_base  10.483795  0.108976        3.0         3.0   4.5
# 3    chronos_bolt_base   0.278185  0.074353        3.0         3.0   4.5
# 4    chronos_bolt_base   0.877710  0.445441        2.0         2.0   3.0
# ..                 ...        ...       ...        ...         ...   ...
# 205           timesfm2   1.056757  0.068474        2.0         5.0   4.5
# 206           timesfm2   1.148564  0.498298        2.0         4.0   4.0
# 207           timesfm2   1.266107  0.493456        5.0         5.0   7.5
# 208           timesfm2   4.085063  0.057008        1.0         1.0   1.5
# 209           timesfm2   2.197155  0.061790        1.0         1.0   1.5
#
# [210 rows x 9 columns]

# %%
all_df[all_df["dataset"] == "bizitobs_application/10S/short"]
# Out:
#                             dataset        domain  num_variates  \
# 0    bizitobs_application/10S/short  Web/CloudOps             2
# 35   bizitobs_application/10S/short  Web/CloudOps             2
# 102  bizitobs_application/10S/short  Web/CloudOps             2
# 113  bizitobs_application/10S/short  Web/CloudOps             2
# 153  bizitobs_application/10S/short  Web/CloudOps             2
# 188  bizitobs_application/10S/short  Web/CloudOps             2
#
#                   model         MASE      Qloss  rank_MASE  rank_Qloss  Rank
# 0     chronos_bolt_base     5.533290   0.053958        3.0         3.0   4.5
# 35   chronos_bolt_small     5.406632   0.034530        2.0         2.0   3.0
# 102   chronos_bolt_mini     7.201342   0.072335        4.0         5.0   6.5
# 113   chronos_bolt_tiny     7.547395   0.069873        5.0         4.0   7.0
# 153            timesfm1  1391.842484  28.269510        6.0         6.0   9.0
# 188            timesfm2     1.560993   0.014470        1.0         1.0   1.5

# %%
dataset_names = all_df["dataset"].unique()

# %%
dataset_names
# Out:
# array(['bizitobs_application/10S/short',
#        'bizitobs_application/10S/medium', 'bizitobs_application/10S/long',
#        'bizitobs_l2c/5T/short', 'bizitobs_l2c/5T/medium',
#        'bizitobs_l2c/5T/long', 'jena_weather/10T/short',
#        'jena_weather/10T/medium', 'jena_weather/10T/long',
#        'bizitobs_service/10S/short', 'bizitobs_service/10S/medium',
#        'bizitobs_service/10S/long', 'bizitobs_l2c/H/short',
#        'bizitobs_l2c/H/medium', 'bizitobs_l2c/H/long', 'solar/D/short',
#        'bitbrains_fast_storage/5T/short',
#        'bitbrains_fast_storage/5T/medium',
#        'bitbrains_fast_storage/5T/long', 'bitbrains_rnd/H/short',
#        'bitbrains_fast_storage/H/short', 'bitbrains_rnd/5T/short',
#        'bitbrains_rnd/5T/medium', 'bitbrains_rnd/5T/long',
#        'jena_weather/H/short', 'jena_weather/H/medium',
#        'jena_weather/H/long', 'solar/W/short', 'jena_weather/D/short',
#        'solar/H/short', 'solar/H/medium', 'solar/H/long',
#        'solar/10T/short', 'solar/10T/medium', 'solar/10T/long'],
#       dtype=object)

# %%
for name in dataset_names:
    #print(name)
    #print(all_df[all_df["dataset"] == name].to_latex(index=False, float_format="%.3f"))
    print(all_df[all_df["dataset"] == name][["model", "MASE", "rank_MASE", "Qloss", "rank_Qloss"]])
    print("\n")
    break
# Out:
#                   model         MASE  rank_MASE      Qloss  rank_Qloss
# 0     chronos_bolt_base     5.533290        3.0   0.053958         3.0
# 35   chronos_bolt_small     5.406632        2.0   0.034530         2.0
# 102   chronos_bolt_mini     7.201342        4.0   0.072335         5.0
# 113   chronos_bolt_tiny     7.547395        5.0   0.069873         4.0
# 153            timesfm1  1391.842484        6.0  28.269510         6.0
# 188            timesfm2     1.560993        1.0   0.014470         1.0

# %%
# new dataframe columns: "Chronos Bolt Base" "Chronos Bolt Small" "Chronos Bolt Mini" "Chronos Bolt Tiny" "TimesFM1" "TimesFM2"
# row: for each dataset name: 4 column (MASE, Qloss, rank_MASE, rank_Qloss, mean(rank_MASE, rank_Qloss))

def create_dataset_df(df, dataset_name):
    dataset_df = df[df["dataset"] == dataset_name]
    dataset_df = dataset_df.drop(columns=["dataset", "domain", "num_variates", "rank_MASE", "rank_Qloss"])
    dataset_df = dataset_df.rename(columns={"model": "Metric"})
    dataset_df = dataset_df.set_index("Metric")
    dataset_df = dataset_df.transpose()
    dataset_df = dataset_df.rename(columns={"chronos_bolt_base": "Chr.B.B",
                                            "chronos_bolt_small": "Chr.B.S",
                                            "chronos_bolt_mini": "Chr.B.M",
                                            "chronos-bolt-mini": "Chr.B.M",
                                            "chronos_bolt_tiny": "Chr.B.T",
                                            "timesfm1": "T.FM1",
                                            "timesfm2": "T.FM2"})
    dataset_df["Best"] = dataset_df.idxmin(axis=1) # add columns best
    return dataset_df

create_dataset_df(all_df, "bizitobs_application/10S/short")
# Out:
# Metric   Chr.B.B   Chr.B.S   Chr.B.M   Chr.B.T        T.FM1     T.FM2   Best
# MASE    5.533290  5.406632  7.201342  7.547395  1391.842484  1.560993  T.FM2
# Qloss   0.053958  0.034530  0.072335  0.069873    28.269510  0.014470  T.FM2
# Rank    4.500000  3.000000  6.500000  7.000000     9.000000  1.500000  T.FM2

# %%
final_df = pd.DataFrame()

for name in dataset_names:
    dataset_df = create_dataset_df(all_df, name)
    dataset_df["dataset, frequency, term"] = name.replace("/", ", ")

    dataset_df = dataset_df.reset_index()
    dataset_df = dataset_df[["dataset, frequency, term", "index", "Chr.B.B", "Chr.B.S", "Chr.B.M",
        "Chr.B.T", "T.FM1", "T.FM2", "Best"]]
    dataset_df = dataset_df.rename(columns={"index": "Metric"})
    dataset_df = dataset_df.rename_axis(index=" ")

    final_df = pd.concat([final_df, dataset_df], ignore_index=True)

# %%
final_df
# Out:
# Metric           dataset, frequency, term Metric   Chr.B.B   Chr.B.S  \
# 0        bizitobs_application, 10S, short   MASE  5.533290  5.406632
# 1        bizitobs_application, 10S, short  Qloss  0.053958  0.034530
# 2        bizitobs_application, 10S, short   Rank  4.500000  3.000000
# 3       bizitobs_application, 10S, medium   MASE  9.720338  9.146529
# 4       bizitobs_application, 10S, medium  Qloss  0.103502  0.084756
# ..                                    ...    ...       ...       ...
# 100                    solar, 10T, medium  Qloss  0.436094  0.452678
# 101                    solar, 10T, medium   Rank  3.000000  4.500000
# 102                      solar, 10T, long   MASE  1.070707  1.188044
# 103                      solar, 10T, long  Qloss  0.443021  0.496991
# 104                      solar, 10T, long   Rank  1.500000  4.500000
#
# Metric    Chr.B.M    Chr.B.T        T.FM1     T.FM2     Best
# 0        7.201342   7.547395  1391.842484  1.560993    T.FM2
# 1        0.072335   0.069873    28.269510  0.014470    T.FM2
# 2        6.500000   7.000000     9.000000  1.500000    T.FM2
# 3       10.972406  11.416669  1199.144679  3.070241    T.FM2
# 4        0.128187   0.115304    30.441737  0.032932    T.FM2
# ..            ...        ...          ...       ...      ...
# 100      0.410149   0.494811  1120.471306  0.515808  Chr.B.M
# 101      1.500000   6.000000     9.000000  7.500000  Chr.B.M
# 102      1.215812   1.288399  5320.462733  1.148564  Chr.B.B
# 103      0.496322   0.534036  2088.004010  0.498298  Chr.B.B
# 104      5.000000   7.500000     9.000000  4.000000  Chr.B.B
#
# [105 rows x 9 columns]

# %%
final_df.to_csv("results/all_results.csv", index=False)

# %%
print(final_df.to_latex(index=False, float_format="%.3f"))
# Out:
# \begin{tabular}{llrrrrrrl}
# \toprule
# dataset, frequency, term & Metric & Chr.B.B & Chr.B.S & Chr.B.M & Chr.B.T & T.FM1 & T.FM2 & Best \\
# \midrule
# bizitobs_application, 10S, short & MASE & 5.533 & 5.407 & 7.201 & 7.547 & 1391.842 & 1.561 & T.FM2 \\
# bizitobs_application, 10S, short & Qloss & 0.054 & 0.035 & 0.072 & 0.070 & 28.270 & 0.014 & T.FM2 \\
# bizitobs_application, 10S, short & Rank & 4.500 & 3.000 & 6.500 & 7.000 & 9.000 & 1.500 & T.FM2 \\
# bizitobs_application, 10S, medium & MASE & 9.720 & 9.147 & 10.972 & 11.417 & 1199.145 & 3.070 & T.FM2 \\
# bizitobs_application, 10S, medium & Qloss & 0.104 & 0.085 & 0.128 & 0.115 & 30.442 & 0.033 & T.FM2 \\
# bizitobs_application, 10S, medium & Rank & 4.500 & 3.000 & 6.500 & 7.000 & 9.000 & 1.500 & T.FM2 \\
# bizitobs_application, 10S, long & MASE & 10.484 & 9.648 & 12.444 & 12.835 & 148.467 & 4.085 & T.FM2 \\
# bizitobs_application, 10S, long & Qloss & 0.109 & 0.092 & 0.150 & 0.137 & 0.500 & 0.057 & T.FM2 \\
# bizitobs_application, 10S, long & Rank & 4.500 & 3.000 & 6.500 & 7.000 & 9.000 & 1.500 & T.FM2 \\
# bizitobs_l2c, 5T, short & MASE & 0.278 & 0.272 & 0.274 & 0.284 & 36.429 & 0.312 & Chr.B.S \\
# bizitobs_l2c, 5T, short & Qloss & 0.074 & 0.073 & 0.073 & 0.075 & 14.173 & 0.084 & Chr.B.M \\
# bizitobs_l2c, 5T, short & Rank & 4.500 & 2.000 & 2.500 & 6.000 & 9.000 & 7.500 & Chr.B.S \\
# bizitobs_l2c, 5T, medium & MASE & 0.878 & 0.920 & 0.886 & 0.840 & 891.926 & 1.023 & Chr.B.T \\
# bizitobs_l2c, 5T, medium & Qloss & 0.445 & 0.462 & 0.451 & 0.420 & 432.168 & 0.528 & Chr.B.T \\
# bizitobs_l2c, 5T, medium & Rank & 3.000 & 6.000 & 4.500 & 1.500 & 9.000 & 7.500 & Chr.B.T \\
# bizitobs_l2c, 5T, long & MASE & 1.241 & 1.357 & 1.330 & 1.258 & 1250.171 & 1.236 & T.FM2 \\
# bizitobs_l2c, 5T, long & Qloss & 0.738 & 0.790 & 0.775 & 0.722 & 633.187 & 0.748 & Chr.B.T \\
# bizitobs_l2c, 5T, long & Rank & 3.000 & 7.500 & 6.000 & 3.500 & 9.000 & 2.500 & T.FM2 \\
# jena_weather, 10T, short & MASE & 0.306 & 0.320 & 0.308 & 0.327 & 130.486 & 0.090 & T.FM2 \\
# jena_weather, 10T, short & Qloss & 0.033 & 0.037 & 0.036 & 0.042 & 27.646 & 0.015 & T.FM2 \\
# jena_weather, 10T, short & Rank & 3.000 & 6.000 & 4.500 & 7.500 & 9.000 & 1.500 & T.FM2 \\
# jena_weather, 10T, medium & MASE & 0.610 & 0.646 & 0.635 & 0.667 & 135.438 & 0.190 & T.FM2 \\
# jena_weather, 10T, medium & Qloss & 0.057 & 0.060 & 0.061 & 0.068 & 27.163 & 0.031 & T.FM2 \\
# jena_weather, 10T, medium & Rank & 3.000 & 5.500 & 5.000 & 7.500 & 9.000 & 1.500 & T.FM2 \\
# jena_weather, 10T, long & MASE & 0.657 & 0.703 & 0.682 & 0.729 & 174.226 & 0.231 & T.FM2 \\
# jena_weather, 10T, long & Qloss & 0.064 & 0.063 & 0.061 & 0.079 & 31.855 & 0.035 & T.FM2 \\
# jena_weather, 10T, long & Rank & 4.000 & 5.500 & 4.000 & 7.500 & 9.000 & 1.500 & T.FM2 \\
# bizitobs_service, 10S, short & MASE & 3.299 & 2.871 & 3.955 & 4.186 & 2192.263 & 1.035 & T.FM2 \\
# bizitobs_service, 10S, short & Qloss & 0.050 & 0.031 & 0.065 & 0.065 & 23.075 & 0.015 & T.FM2 \\
# bizitobs_service, 10S, short & Rank & 4.500 & 3.000 & 6.500 & 7.000 & 9.000 & 1.500 & T.FM2 \\
# bizitobs_service, 10S, medium & MASE & 4.958 & 4.618 & 5.850 & 5.972 & 2338.311 & 1.526 & T.FM2 \\
# bizitobs_service, 10S, medium & Qloss & 0.095 & 0.081 & 0.119 & 0.113 & 36.344 & 0.038 & T.FM2 \\
# bizitobs_service, 10S, medium & Rank & 4.500 & 3.000 & 6.500 & 7.000 & 9.000 & 1.500 & T.FM2 \\
# bizitobs_service, 10S, long & MASE & 5.280 & 4.824 & 6.522 & 6.600 & 853.987 & 2.197 & T.FM2 \\
# bizitobs_service, 10S, long & Qloss & 0.112 & 0.095 & 0.144 & 0.133 & 24.138 & 0.062 & T.FM2 \\
# bizitobs_service, 10S, long & Rank & 4.500 & 3.000 & 6.500 & 7.000 & 9.000 & 1.500 & T.FM2 \\
# bizitobs_l2c, H, short & MASE & 0.432 & 0.485 & 0.495 & 0.473 & 484.719 & 0.782 & Chr.B.B \\
# bizitobs_l2c, H, short & Qloss & 0.189 & 0.204 & 0.208 & 0.203 & 258.594 & 0.345 & Chr.B.B \\
# bizitobs_l2c, H, short & Rank & 1.500 & 4.500 & 6.000 & 3.000 & 9.000 & 7.500 & Chr.B.B \\
# bizitobs_l2c, H, medium & MASE & 0.495 & 0.570 & 0.521 & 0.600 & 97.963 & 1.184 & Chr.B.B \\
# bizitobs_l2c, H, medium & Qloss & 0.254 & 0.285 & 0.266 & 0.304 & 54.232 & 0.641 & Chr.B.B \\
# bizitobs_l2c, H, medium & Rank & 1.500 & 4.500 & 3.000 & 6.000 & 9.000 & 7.500 & Chr.B.B \\
# bizitobs_l2c, H, long & MASE & 0.556 & 0.612 & 0.611 & 0.606 & 2042.632 & 1.299 & Chr.B.B \\
# bizitobs_l2c, H, long & Qloss & 0.278 & 0.295 & 0.296 & 0.306 & 1082.585 & 0.728 & Chr.B.B \\
# bizitobs_l2c, H, long & Rank & 1.500 & 5.000 & 4.500 & 4.000 & 9.000 & 7.500 & Chr.B.B \\
# solar, D, short & MASE & 0.982 & 0.995 & 0.981 & 0.993 & 4.354 & 0.971 & T.FM2 \\
# solar, D, short & Qloss & 0.287 & 0.286 & 0.279 & 0.282 & 1.248 & 0.278 & T.FM2 \\
# solar, D, short & Rank & 5.500 & 7.000 & 3.000 & 5.500 & 9.000 & 1.500 & T.FM2 \\
# bitbrains_fast_storage, 5T, short & MASE & 0.745 & 0.770 & 0.808 & 0.864 & 293.558 & 0.731 & T.FM2 \\
# bitbrains_fast_storage, 5T, short & Qloss & 0.454 & 0.435 & 0.434 & 0.420 & 131.061 & 0.447 & Chr.B.T \\
# bitbrains_fast_storage, 5T, short & Rank & 4.500 & 4.500 & 5.000 & 5.500 & 9.000 & 3.000 & T.FM2 \\
# bitbrains_fast_storage, 5T, medium & MASE & 1.048 & 1.060 & 1.070 & 1.115 & 273.811 & 1.075 & Chr.B.B \\
# bitbrains_fast_storage, 5T, medium & Qloss & 0.755 & 0.867 & 0.828 & 0.814 & 189.791 & 0.886 & Chr.B.B \\
# bitbrains_fast_storage, 5T, medium & Rank & 1.500 & 4.000 & 4.500 & 6.000 & 9.000 & 6.500 & Chr.B.B \\
# bitbrains_fast_storage, 5T, long & MASE & 0.938 & 0.953 & 0.967 & 0.994 & 403.898 & 0.980 & Chr.B.B \\
# bitbrains_fast_storage, 5T, long & Qloss & 0.748 & 0.753 & 0.749 & 0.750 & 164.589 & 0.909 & Chr.B.B \\
# bitbrains_fast_storage, 5T, long & Rank & 1.500 & 4.000 & 4.000 & 6.500 & 9.000 & 6.500 & Chr.B.B \\
# bitbrains_rnd, H, short & MASE & 5.897 & 5.880 & 5.882 & 5.951 & 364.946 & 5.987 & Chr.B.S \\
# bitbrains_rnd, H, short & Qloss & 0.624 & 0.623 & 0.585 & 0.604 & 473.143 & 0.649 & Chr.B.M \\
# bitbrains_rnd, H, short & Rank & 5.000 & 2.500 & 2.500 & 5.000 & 9.000 & 7.500 & Chr.B.S \\
# bitbrains_fast_storage, H, short & MASE & 1.070 & 1.080 & 1.105 & 1.150 & 156.838 & 1.095 & Chr.B.B \\
# bitbrains_fast_storage, H, short & Qloss & 0.774 & 0.589 & 0.596 & 0.593 & 47.147 & 0.689 & Chr.B.S \\
# bitbrains_fast_storage, H, short & Rank & 3.500 & 2.500 & 5.500 & 6.000 & 9.000 & 5.000 & Chr.B.S \\
# bitbrains_rnd, 5T, short & MASE & 1.705 & 1.720 & 1.740 & 1.755 & 208.669 & 1.769 & Chr.B.B \\
# bitbrains_rnd, 5T, short & Qloss & 0.438 & 0.453 & 0.475 & 0.482 & 83.292 & 0.463 & Chr.B.B \\
# bitbrains_rnd, 5T, short & Rank & 1.500 & 3.000 & 5.000 & 6.500 & 9.000 & 6.500 & Chr.B.B \\
# bitbrains_rnd, 5T, medium & MASE & 4.449 & 4.474 & 4.492 & 4.519 & 437.821 & 4.596 & Chr.B.B \\
# bitbrains_rnd, 5T, medium & Qloss & 0.605 & 0.792 & 0.716 & 0.697 & 139.018 & 0.736 & Chr.B.B \\
# bitbrains_rnd, 5T, medium & Rank & 1.500 & 4.500 & 4.500 & 5.000 & 9.000 & 7.000 & Chr.B.B \\
# bitbrains_rnd, 5T, long & MASE & 3.397 & 3.413 & 3.443 & 3.488 & 393.744 & 3.604 & Chr.B.B \\
# bitbrains_rnd, 5T, long & Qloss & 0.756 & 0.756 & 0.750 & 0.917 & 178.114 & 0.714 & T.FM2 \\
# bitbrains_rnd, 5T, long & Rank & 2.500 & 4.000 & 4.000 & 6.500 & 9.000 & 5.500 & Chr.B.B \\
# jena_weather, H, short & MASE & 0.536 & 0.540 & 0.548 & 0.549 & 226.170 & 0.525 & T.FM2 \\
# jena_weather, H, short & Qloss & 0.042 & 0.043 & 0.042 & 0.042 & 10.617 & 0.045 & Chr.B.B \\
# jena_weather, H, short & Rank & 2.500 & 5.000 & 5.500 & 6.000 & 9.000 & 3.500 & Chr.B.B \\
# jena_weather, H, medium & MASE & 0.747 & 0.721 & 0.729 & 0.789 & 185.596 & 0.864 & Chr.B.S \\
# jena_weather, H, medium & Qloss & 0.054 & 0.058 & 0.059 & 0.058 & 16.609 & 0.066 & Chr.B.B \\
# jena_weather, H, medium & Rank & 3.500 & 2.500 & 4.000 & 5.000 & 9.000 & 7.500 & Chr.B.S \\
# jena_weather, H, long & MASE & 1.028 & 1.060 & 1.063 & 1.112 & 390.758 & 1.057 & Chr.B.B \\
# jena_weather, H, long & Qloss & 0.062 & 0.068 & 0.067 & 0.066 & 24.919 & 0.068 & Chr.B.B \\
# jena_weather, H, long & Rank & 1.500 & 5.000 & 5.500 & 6.000 & 9.000 & 4.500 & Chr.B.B \\
# solar, W, short & MASE & 0.980 & 0.991 & 0.994 & 0.952 & 1.792 & 1.282 & Chr.B.T \\
# solar, W, short & Qloss & 0.133 & 0.136 & 0.135 & 0.132 & 0.307 & 0.171 & Chr.B.T \\
# solar, W, short & Rank & 3.000 & 5.000 & 5.500 & 1.500 & 9.000 & 7.500 & Chr.B.T \\
# jena_weather, D, short & MASE & 1.051 & 1.028 & 1.034 & 1.024 & 97.927 & 1.243 & Chr.B.T \\
# jena_weather, D, short & Qloss & 0.045 & 0.047 & 0.047 & 0.047 & 10.015 & 0.058 & Chr.B.B \\
# jena_weather, D, short & Rank & 4.500 & 3.500 & 5.000 & 2.000 & 9.000 & 7.500 & Chr.B.T \\
# solar, H, short & MASE & 0.813 & 0.852 & 0.860 & 0.867 & 8.797 & 1.022 & Chr.B.B \\
# solar, H, short & Qloss & 0.298 & 0.303 & 0.311 & 0.313 & 4.876 & 0.407 & Chr.B.B \\
# solar, H, short & Rank & 1.500 & 3.000 & 4.500 & 6.000 & 9.000 & 7.500 & Chr.B.B \\
# solar, H, medium & MASE & 0.931 & 0.926 & 0.906 & 0.903 & 24.755 & 0.959 & Chr.B.T \\
# solar, H, medium & Qloss & 0.368 & 0.356 & 0.352 & 0.342 & 10.359 & 0.376 & Chr.B.T \\
# solar, H, medium & Rank & 6.000 & 4.500 & 3.000 & 1.500 & 9.000 & 7.500 & Chr.B.T \\
# solar, H, long & MASE & 1.033 & 0.957 & 0.946 & 0.935 & 97.158 & 1.266 & Chr.B.T \\
# solar, H, long & Qloss & 0.405 & 0.373 & 0.370 & 0.354 & 47.880 & 0.493 & Chr.B.T \\
# solar, H, long & Rank & 6.000 & 4.500 & 3.000 & 1.500 & 9.000 & 7.500 & Chr.B.T \\
# solar, 10T, short & MASE & 0.991 & 0.947 & 1.060 & 0.923 & 2959.781 & 1.477 & Chr.B.T \\
# solar, 10T, short & Qloss & 0.511 & 0.498 & 0.563 & 0.488 & 1727.726 & 0.804 & Chr.B.T \\
# solar, 10T, short & Rank & 4.500 & 3.000 & 6.000 & 1.500 & 9.000 & 7.500 & Chr.B.T \\
# solar, 10T, medium & MASE & 1.027 & 1.065 & 0.978 & 1.157 & 2771.306 & 1.169 & Chr.B.M \\
# solar, 10T, medium & Qloss & 0.436 & 0.453 & 0.410 & 0.495 & 1120.471 & 0.516 & Chr.B.M \\
# solar, 10T, medium & Rank & 3.000 & 4.500 & 1.500 & 6.000 & 9.000 & 7.500 & Chr.B.M \\
# solar, 10T, long & MASE & 1.071 & 1.188 & 1.216 & 1.288 & 5320.463 & 1.149 & Chr.B.B \\
# solar, 10T, long & Qloss & 0.443 & 0.497 & 0.496 & 0.534 & 2088.004 & 0.498 & Chr.B.B \\
# solar, 10T, long & Rank & 1.500 & 4.500 & 5.000 & 7.500 & 9.000 & 4.000 & Chr.B.B \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# ### More Results

# %%
import json

# read the json file
with open("results/data/domain_dict.json", "r") as f:
    domain_data = json.load(f)

domain_data
# Out:
# {'bitbrains_fast_storage': 'Web/CloudOps',
#  'bitbrains_rnd': 'Web/CloudOps',
#  'bizitobs_l2c': 'Web/CloudOps',
#  'bizitobs_application': 'Web/CloudOps',
#  'bizitobs_service': 'Web/CloudOps',
#  'jena_weather': 'Weather',
#  'solar': 'Energy'}

# %%
final_df["Dataset"] = final_df["dataset, frequency, term"].apply(
    lambda x: x.split(", ")[0] if len(x.split(", ")) > 0 else "Unknown")
final_df["Domain"] = final_df["Dataset"].apply(lambda x: domain_data[x] if x in domain_data else "Unknown")
final_df["Term"] = final_df["dataset, frequency, term"].apply(
    lambda x: x.split(", ")[2] if len(x.split(", ")) > 2 else "Unknown")
final_df["Frequency"] = final_df["dataset, frequency, term"].apply(
    lambda x: x.split(", ")[1] if len(x.split(", ")) > 1 else "Unknown")

final_df = final_df[["Dataset", "Domain", "Term", "Frequency", "Metric",
    "Chr.B.B", "Chr.B.S", "Chr.B.M", "Chr.B.T", "T.FM1", "T.FM2", "Best"]]
final_df
# Out:
# Metric               Dataset        Domain    Term Frequency Metric   Chr.B.B  \
# 0       bizitobs_application  Web/CloudOps   short       10S   MASE  5.533290
# 1       bizitobs_application  Web/CloudOps   short       10S  Qloss  0.053958
# 2       bizitobs_application  Web/CloudOps   short       10S   Rank  4.500000
# 3       bizitobs_application  Web/CloudOps  medium       10S   MASE  9.720338
# 4       bizitobs_application  Web/CloudOps  medium       10S  Qloss  0.103502
# ..                       ...           ...     ...       ...    ...       ...
# 100                    solar        Energy  medium       10T  Qloss  0.436094
# 101                    solar        Energy  medium       10T   Rank  3.000000
# 102                    solar        Energy    long       10T   MASE  1.070707
# 103                    solar        Energy    long       10T  Qloss  0.443021
# 104                    solar        Energy    long       10T   Rank  1.500000
#
# Metric   Chr.B.S    Chr.B.M    Chr.B.T        T.FM1     T.FM2     Best
# 0       5.406632   7.201342   7.547395  1391.842484  1.560993    T.FM2
# 1       0.034530   0.072335   0.069873    28.269510  0.014470    T.FM2
# 2       3.000000   6.500000   7.000000     9.000000  1.500000    T.FM2
# 3       9.146529  10.972406  11.416669  1199.144679  3.070241    T.FM2
# 4       0.084756   0.128187   0.115304    30.441737  0.032932    T.FM2
# ..           ...        ...        ...          ...       ...      ...
# 100     0.452678   0.410149   0.494811  1120.471306  0.515808  Chr.B.M
# 101     4.500000   1.500000   6.000000     9.000000  7.500000  Chr.B.M
# 102     1.188044   1.215812   1.288399  5320.462733  1.148564  Chr.B.B
# 103     0.496991   0.496322   0.534036  2088.004010  0.498298  Chr.B.B
# 104     4.500000   5.000000   7.500000     9.000000  4.000000  Chr.B.B
#
# [105 rows x 12 columns]

# %%
domain_results = final_df.groupby(["Domain", "Metric"]).agg({
    "Chr.B.B": "mean",
    "Chr.B.S": "mean",
    "Chr.B.M": "mean",
    "Chr.B.T": "mean",
    "T.FM1": "mean",
    "T.FM2": "mean"
}).reset_index()
domain_results["Best"] = domain_results[["Chr.B.B", "Chr.B.S", "Chr.B.M", "Chr.B.T", "T.FM1", "T.FM2"]].idxmin(axis=1)

domain_results
# Out:
# Metric        Domain Metric   Chr.B.B   Chr.B.S   Chr.B.M   Chr.B.T  \
# 0             Energy   MASE  0.978315  0.990242  0.992473  1.002300
# 1             Energy  Qloss  0.360238  0.362762  0.364672  0.367498
# 2             Energy   Rank  3.875000  4.500000  3.937500  3.875000
# 3            Weather   MASE  0.704962  0.716802  0.714102  0.742491
# 4            Weather  Qloss  0.050921  0.053554  0.053563  0.057388
# 5            Weather   Rank  3.142857  4.714286  4.785714  5.928571
# 6       Web/CloudOps   MASE  3.120157  3.004048  3.528463  3.622740
# 7       Web/CloudOps  Qloss  0.382827  0.389877  0.394053  0.397024
# 8       Web/CloudOps   Rank  3.175000  3.825000  5.025000  5.650000
#
# Metric        T.FM1     T.FM2     Best
# 0       1398.550826  1.161931  Chr.B.B
# 1        625.108813  0.443007  Chr.B.B
# 2          9.000000  6.312500  Chr.B.B
# 3        191.514484  0.600010    T.FM2
# 4         21.260529  0.045489    T.FM2
# 5          9.000000  3.928571  Chr.B.B
# 6        773.056968  1.957359    T.FM2
# 7        201.193159  0.439267  Chr.B.B
# 8          9.000000  4.825000  Chr.B.B

# %%
term_results = final_df.groupby(["Term", "Metric"]).agg({
    "Chr.B.B": "mean",
    "Chr.B.S": "mean",
    "Chr.B.M": "mean",
    "Chr.B.T": "mean",
    "T.FM1": "mean",
    "T.FM2": "mean"
}).reset_index()
term_results["Best"] = term_results[["Chr.B.B", "Chr.B.S", "Chr.B.M", "Chr.B.T", "T.FM1", "T.FM2"]].idxmin(axis=1)

term_results
# Out:
# Metric    Term Metric   Chr.B.B   Chr.B.S   Chr.B.M   Chr.B.T        T.FM1  \
# 0         long   MASE  2.568424  2.471569  2.922420  2.984658  1107.550333
# 1         long  Qloss  0.371390  0.378322  0.385969  0.399802   427.577050
# 2         long   Rank  3.050000  4.600000  4.900000  5.700000     9.000000
# 3       medium   MASE  2.486340  2.414703  2.703918  2.797745   835.607148
# 4       medium  Qloss  0.317459  0.349865  0.338989  0.342546   205.659694
# 5       medium   Rank  3.200000  4.200000  4.300000  5.250000     9.000000
# 6        short   MASE  1.641117  1.610520  1.816291  1.856440   570.571504
# 7        short  Qloss  0.267093  0.252842  0.261587  0.257248   189.412663
# 8        short   Rank  3.600000  3.833333  4.900000  5.066667     9.000000
#
# Metric     T.FM2     Best
# 0       1.710321    T.FM2
# 1       0.431292  Chr.B.B
# 2       4.250000  Chr.B.B
# 3       1.565683    T.FM2
# 4       0.385105  Chr.B.B
# 5       5.550000  Chr.B.B
# 6       1.325511    T.FM2
# 7       0.298924  Chr.B.S
# 8       5.100000  Chr.B.B

# %%
frequency_results = final_df.groupby(["Frequency", "Metric"]).agg({
    "Chr.B.B": "mean",
    "Chr.B.S": "mean",
    "Chr.B.M": "mean",
    "Chr.B.T": "mean",
    "T.FM1": "mean",
    "T.FM2": "mean"
}).reset_index()
frequency_results["Frequency"] = frequency_results["Frequency"].map({
    "10S": "10 seconds",
    "5T": "5 minutes",
    "10T": "10 minute",
    "H": "1 hour",
    "D": "1 day",
    "W": "1 week",
})
# sort by frequency
frequency_results = frequency_results.sort_values(by=["Frequency", "Metric"])

frequency_results["Best"] = frequency_results[["Chr.B.B", "Chr.B.S", "Chr.B.M", "Chr.B.T", "T.FM1", "T.FM2"]].idxmin(axis=1)

frequency_results
# Out:
# Metric   Frequency Metric   Chr.B.B   Chr.B.S   Chr.B.M   Chr.B.T  \
# 9            1 day   MASE  1.016458  1.011439  1.007155  1.008487
# 10           1 day  Qloss  0.166183  0.166360  0.163197  0.164470
# 11           1 day   Rank  5.000000  5.250000  4.000000  3.750000
# 12          1 hour   MASE  1.230735  1.243955  1.242433  1.266969
# 13          1 hour  Qloss  0.304430  0.290577  0.286801  0.289601
# 14          1 hour   Rank  3.090909  3.954545  4.272727  4.545455
# 15          1 week   MASE  0.979691  0.990633  0.993680  0.952312
# 16          1 week  Qloss  0.132579  0.136405  0.135327  0.132001
# 17          1 week   Rank  3.000000  5.000000  5.500000  1.500000
# 3        10 minute   MASE  0.776758  0.811577  0.812932  0.848411
# 4        10 minute  Qloss  0.257333  0.267990  0.271274  0.284366
# 5        10 minute   Rank  3.166667  4.833333  4.333333  6.250000
# 0       10 seconds   MASE  6.545707  6.085683  7.824120  8.092802
# 1       10 seconds  Qloss  0.087267  0.069819  0.113045  0.105461
# 2       10 seconds   Rank  4.500000  3.000000  6.500000  7.000000
# 6        5 minutes   MASE  1.630990  1.659994  1.667854  1.679711
# 7        5 minutes  Qloss  0.557067  0.598020  0.583437  0.588519
# 8        5 minutes   Rank  2.611111  4.388889  4.444444  5.222222
#
# Metric        T.FM1     T.FM2     Best
# 9         51.140927  1.106763  Chr.B.M
# 10         5.631724  0.167940  Chr.B.M
# 11         9.000000  4.500000  Chr.B.T
# 12       370.939218  1.458300  Chr.B.B
# 13       184.632643  0.409819  Chr.B.M
# 14         9.000000  6.636364  Chr.B.B
# 15         1.791770  1.282103  Chr.B.T
# 16         0.306911  0.171318  Chr.B.T
# 17         9.000000  7.500000  Chr.B.T
# 3       1915.283466  0.717685    T.FM2
# 4        837.144209  0.316485  Chr.B.B
# 5          9.000000  3.916667  Chr.B.B
# 0       1354.002554  2.245648    T.FM2
# 1         23.794736  0.036572    T.FM2
# 2          9.000000  1.500000    T.FM2
# 6        465.558470  1.702864  Chr.B.B
# 7        218.377142  0.612698  Chr.B.B
# 8          9.000000  5.833333  Chr.B.B

# %%
print(domain_results.to_latex(index=False, float_format="%.3f"))
# Out:
# \begin{tabular}{llrrrrrrl}
# \toprule
# Domain & Metric & Chr.B.B & Chr.B.S & Chr.B.M & Chr.B.T & T.FM1 & T.FM2 & Best \\
# \midrule
# Energy & MASE & 0.978 & 0.990 & 0.992 & 1.002 & 1398.551 & 1.162 & Chr.B.B \\
# Energy & Qloss & 0.360 & 0.363 & 0.365 & 0.367 & 625.109 & 0.443 & Chr.B.B \\
# Energy & Rank & 3.875 & 4.500 & 3.938 & 3.875 & 9.000 & 6.312 & Chr.B.B \\
# Weather & MASE & 0.705 & 0.717 & 0.714 & 0.742 & 191.514 & 0.600 & T.FM2 \\
# Weather & Qloss & 0.051 & 0.054 & 0.054 & 0.057 & 21.261 & 0.045 & T.FM2 \\
# Weather & Rank & 3.143 & 4.714 & 4.786 & 5.929 & 9.000 & 3.929 & Chr.B.B \\
# Web/CloudOps & MASE & 3.120 & 3.004 & 3.528 & 3.623 & 773.057 & 1.957 & T.FM2 \\
# Web/CloudOps & Qloss & 0.383 & 0.390 & 0.394 & 0.397 & 201.193 & 0.439 & Chr.B.B \\
# Web/CloudOps & Rank & 3.175 & 3.825 & 5.025 & 5.650 & 9.000 & 4.825 & Chr.B.B \\
# \bottomrule
# \end{tabular}

# %%
print(term_results.to_latex(index=False, float_format="%.3f"))
# Out:
# \begin{tabular}{llrrrrrrl}
# \toprule
# Term & Metric & Chr.B.B & Chr.B.S & Chr.B.M & Chr.B.T & T.FM1 & T.FM2 & Best \\
# \midrule
# long & MASE & 2.568 & 2.472 & 2.922 & 2.985 & 1107.550 & 1.710 & T.FM2 \\
# long & Qloss & 0.371 & 0.378 & 0.386 & 0.400 & 427.577 & 0.431 & Chr.B.B \\
# long & Rank & 3.050 & 4.600 & 4.900 & 5.700 & 9.000 & 4.250 & Chr.B.B \\
# medium & MASE & 2.486 & 2.415 & 2.704 & 2.798 & 835.607 & 1.566 & T.FM2 \\
# medium & Qloss & 0.317 & 0.350 & 0.339 & 0.343 & 205.660 & 0.385 & Chr.B.B \\
# medium & Rank & 3.200 & 4.200 & 4.300 & 5.250 & 9.000 & 5.550 & Chr.B.B \\
# short & MASE & 1.641 & 1.611 & 1.816 & 1.856 & 570.572 & 1.326 & T.FM2 \\
# short & Qloss & 0.267 & 0.253 & 0.262 & 0.257 & 189.413 & 0.299 & Chr.B.S \\
# short & Rank & 3.600 & 3.833 & 4.900 & 5.067 & 9.000 & 5.100 & Chr.B.B \\
# \bottomrule
# \end{tabular}

# %%
print(frequency_results.to_latex(index=False, float_format="%.3f"))
# Out:
# \begin{tabular}{llrrrrrrl}
# \toprule
# Frequency & Metric & Chr.B.B & Chr.B.S & Chr.B.M & Chr.B.T & T.FM1 & T.FM2 & Best \\
# \midrule
# 1 day & MASE & 1.016 & 1.011 & 1.007 & 1.008 & 51.141 & 1.107 & Chr.B.M \\
# 1 day & Qloss & 0.166 & 0.166 & 0.163 & 0.164 & 5.632 & 0.168 & Chr.B.M \\
# 1 day & Rank & 5.000 & 5.250 & 4.000 & 3.750 & 9.000 & 4.500 & Chr.B.T \\
# 1 hour & MASE & 1.231 & 1.244 & 1.242 & 1.267 & 370.939 & 1.458 & Chr.B.B \\
# 1 hour & Qloss & 0.304 & 0.291 & 0.287 & 0.290 & 184.633 & 0.410 & Chr.B.M \\
# 1 hour & Rank & 3.091 & 3.955 & 4.273 & 4.545 & 9.000 & 6.636 & Chr.B.B \\
# 1 week & MASE & 0.980 & 0.991 & 0.994 & 0.952 & 1.792 & 1.282 & Chr.B.T \\
# 1 week & Qloss & 0.133 & 0.136 & 0.135 & 0.132 & 0.307 & 0.171 & Chr.B.T \\
# 1 week & Rank & 3.000 & 5.000 & 5.500 & 1.500 & 9.000 & 7.500 & Chr.B.T \\
# 10 minute & MASE & 0.777 & 0.812 & 0.813 & 0.848 & 1915.283 & 0.718 & T.FM2 \\
# 10 minute & Qloss & 0.257 & 0.268 & 0.271 & 0.284 & 837.144 & 0.316 & Chr.B.B \\
# 10 minute & Rank & 3.167 & 4.833 & 4.333 & 6.250 & 9.000 & 3.917 & Chr.B.B \\
# 10 seconds & MASE & 6.546 & 6.086 & 7.824 & 8.093 & 1354.003 & 2.246 & T.FM2 \\
# 10 seconds & Qloss & 0.087 & 0.070 & 0.113 & 0.105 & 23.795 & 0.037 & T.FM2 \\
# 10 seconds & Rank & 4.500 & 3.000 & 6.500 & 7.000 & 9.000 & 1.500 & T.FM2 \\
# 5 minutes & MASE & 1.631 & 1.660 & 1.668 & 1.680 & 465.558 & 1.703 & Chr.B.B \\
# 5 minutes & Qloss & 0.557 & 0.598 & 0.583 & 0.589 & 218.377 & 0.613 & Chr.B.B \\
# 5 minutes & Rank & 2.611 & 4.389 & 4.444 & 5.222 & 9.000 & 5.833 & Chr.B.B \\
# \bottomrule
# \end{tabular}
